# %%
import nltk , sys,tweepy,csv,re
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:/Users/KIIT/Documents/minor/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv')

# %%
data.head(3)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 2  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# ...

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# %%
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
data['subjectivity'] = data['reviews.text'].apply(getSubjectivity)

# %%
data.head(3)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 2  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# ...

# %%
data['polarity'] = data['reviews.text'].apply(getPolarity)

# %%
data.head(3)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 2  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# ...

# %%
p = 0
n = 0
nt = 0
def getAnalysis(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
data['review_analysis'] = data['polarity'].apply(getAnalysis)

# %%
data.head(3)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 1  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# 2  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
#
#           brand                                         categories  \
# 0  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 1  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
# 2  Amazonbasics  AA,AAA,Health,Electronics,Health & Household,C...
#
#   primaryCategories                                          imageURLs  \
# ...

# %%
data.head(10)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 5  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 6  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 7  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 8  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
# 9  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z  2019-04-25T09:08:16Z
#
#                                                 name                  asins  \
# 0  AmazonBasics AAA Performance Alkaline Batterie...  B00QWO9P0O,B00LH3DMUO
# ...

# %%
data['review_analysis']
# Out:
# 0        Negative
# 1        Negative
# 2        Positive
# 3        Positive
# 4        Positive
#            ...
# 28327    Positive
# 28328    Positive
# 28329    Positive
# 28330    Positive
# 28331    Positive
# Name: review_analysis, Length: 28332, dtype: object

# %%
p=0
n=0
nt=0

# %%
def getCount(state):
    if state == 'Positive':
        p += 1
    elif state == 'Neutral':
        nt += 1
    else:
        n += 1

# %%
res = data['review_analysis']

# %%
res
# Out:
# 0        Negative
# 1        Negative
# 2        Positive
# 3        Positive
# 4        Positive
#            ...
# 28327    Positive
# 28328    Positive
# 28329    Positive
# 28330    Positive
# 28331    Positive
# Name: review_analysis, Length: 28332, dtype: object

# %%
res = list(res)

# %%
res
# Out:
# ['Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Negative',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Positive',
#  'Neutral',
#  'Positive',
# ...

# %%
p
# Out:
# 0

# %%
n
# Out:
# 0

# %%
nt
# Out:
# 0

# %%
data.to_csv('C:/Users/KIIT/Documents/minor/analyzed_data_textblob3.csv')
