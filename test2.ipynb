# %%
import nltk , sys , tweepy , csv , re
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:/Users/KIIT/Documents/minor/Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products.csv')

# %%
data.head(3)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# 0  Computers,Electronics Features,Tablets,Electro...       Electronics
# 1  Computers,Electronics Features,Tablets,Electro...       Electronics
# 2  Computers,Electronics Features,Tablets,Electro...       Electronics
#
#                                            imageURLs  \
# 0  https://pisces.bbystatic.com/image2/BestBuy_US...
# ...

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# %%
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
data['subjectivity'] = data['reviews.text'].apply(getSubjectivity)

# %%
data.head(3)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# 0  Computers,Electronics Features,Tablets,Electro...       Electronics
# 1  Computers,Electronics Features,Tablets,Electro...       Electronics
# 2  Computers,Electronics Features,Tablets,Electro...       Electronics
#
#                                            imageURLs  \
# 0  https://pisces.bbystatic.com/image2/BestBuy_US...
# ...

# %%
data['polarity'] = data['reviews.text'].apply(getPolarity)

# %%
data.head(3)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# 0  Computers,Electronics Features,Tablets,Electro...       Electronics
# 1  Computers,Electronics Features,Tablets,Electro...       Electronics
# 2  Computers,Electronics Features,Tablets,Electro...       Electronics
#
#                                            imageURLs  \
# 0  https://pisces.bbystatic.com/image2/BestBuy_US...
# ...

# %%
def getAnalysis(score):
    if score <0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'

# %%
data['review_analysis'] = data['polarity'].apply(getAnalysis)

# %%
data.head(3)
# Out:
#                      id             dateAdded           dateUpdated  \
# 0  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 1  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
# 2  AVqVGZNvQMlgsOJE6eUY  2017-03-03T16:56:05Z  2018-10-25T16:36:31Z
#
#                                                 name       asins   brand  \
# 0  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 1  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
# 2  Amazon Kindle E-Reader 6" Wifi (8th Generation...  B00ZV9PXP2  Amazon
#
#                                           categories primaryCategories  \
# 0  Computers,Electronics Features,Tablets,Electro...       Electronics
# 1  Computers,Electronics Features,Tablets,Electro...       Electronics
# 2  Computers,Electronics Features,Tablets,Electro...       Electronics
#
#                                            imageURLs  \
# 0  https://pisces.bbystatic.com/image2/BestBuy_US...
# ...

# %%
p=0
n=0
nt=0
def getCount(state):
    if state == 'Positive':
        p += 1
    elif state == 'Neutral':
        nt += 1
    else:
        n += 1

# %%
res = data['review_analysis']

# %%
res = list(res)

# %%
p = 0
n = 0
nt = 0
for i in res:
    if i == 'Positive':
        p += 1
    elif i == 'Neutral':
        nt += 1
    else:
        n += 1

# %%
p
# Out:
# 4471

# %%
n
# Out:
# 236

# %%
nt
# Out:
# 293

# %%
data.to_csv('C:/Users/KIIT/Documents/minor/analyzed_data_textblob2.csv')

# %%
data3=pd.read_csv('C:/Users/KIIT/Documents/minor/analyzed_data_textblob3.csv')

# %%
data3.head(5)
# Out:
#    Unnamed: 0                    id             dateAdded  \
# 0           0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 1           1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 2           2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 3           3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 4           4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
#
#             dateUpdated                                               name  \
# 0  2019-04-25T09:08:16Z  AmazonBasics AAA Performance Alkaline Batterie...
# 1  2019-04-25T09:08:16Z  AmazonBasics AAA Performance Alkaline Batterie...
# 2  2019-04-25T09:08:16Z  AmazonBasics AAA Performance Alkaline Batterie...
# 3  2019-04-25T09:08:16Z  AmazonBasics AAA Performance Alkaline Batterie...
# 4  2019-04-25T09:08:16Z  AmazonBasics AAA Performance Alkaline Batterie...
#
#                    asins         brand  \
# 0  B00QWO9P0O,B00LH3DMUO  Amazonbasics
# 1  B00QWO9P0O,B00LH3DMUO  Amazonbasics
# 2  B00QWO9P0O,B00LH3DMUO  Amazonbasics
# ...

# %%
data2=pd.read_csv('C:/Users/KIIT/Documents/minor/analyzed_data_textblob2.csv')

# %%
data1=pd.read_csv('C:/Users/KIIT/Documents/minor/analyzed_data_textblob.csv')

# %%
resneg = data1[data1['review_analysis'] == 'Negative']

# %%
resneg
# Out:
#       Unnamed: 0                    id       asins   brand  \
# 39            39  AVpfBEWcilAPnD_xTGb7  B002Y27P3M  Amazon
# 96            96  AV00lzP7GV-KLJ3ac0uk  B01LW1MS9C  Amazon
# 108          108  AVpfpzCi1cnluZ0-oxEr  B00DOPNLJ0  Amazon
# 152          152  AV00l7jV-jtxr-f30lnX  B01LW1MS9C  Amazon
# 165          165  AV3as-VX-jtxr-f3_PPu  B01LW1MS9C  Amazon
# ...          ...                   ...         ...     ...
# 1589        1589  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1590        1590  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1592        1592  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1594        1594  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1596        1596  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
#
#                                              categories colors  \
# 39              Kindle Store,Amazon Devices,Electronics    NaN
# 96                                       Amazon Devices    NaN
# 108                                      Amazon Devices    NaN
# ...

# %%
resneut = data1[data1['review_analysis'] == 'Neutral']

# %%
resneut
# Out:
#       Unnamed: 0                    id       asins   brand  \
# 16            16  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 18            18  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 250          250  AV1T19k3GV-KLJ3adSMS  B01A08ECQY  Amazon
# 336          336  AVpfLiCSilAPnD_xWpk_  B00CX5P8FC  Amazon
# 340          340  AVpfLiCSilAPnD_xWpk_  B00CX5P8FC  Amazon
# 365          365  AVpfLiCSilAPnD_xWpk_  B00CX5P8FC  Amazon
# 368          368  AVpfLiCSilAPnD_xWpk_  B00CX5P8FC  Amazon
# 398          398  AVpfLiCSilAPnD_xWpk_  B00CX5P8FC  Amazon
# 414          414  AVpfLiCSilAPnD_xWpk_  B00CX5P8FC  Amazon
# 451          451  AVpfLiCSilAPnD_xWpk_  B00CX5P8FC  Amazon
# 455          455  AVsRjfwAU2_QcyX9PHqe  B01J2G4VBG  Amazon
# 461          461  AVsRjfwAU2_QcyX9PHqe  B01J2G4VBG  Amazon
# 465          465  AVsRjfwAU2_QcyX9PHqe  B01J2G4VBG  Amazon
# 467          467  AVsRjfwAU2_QcyX9PHqe  B01J2G4VBG  Amazon
# 486          486  AVzRloqLGV-KLJ3aavBd  B07194GPJV  Amazon
# ...

# %%
data3
# Out:
#        Unnamed: 0                    id             dateAdded  \
# 0               0  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 1               1  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 2               2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 3               3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 4               4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# ...           ...                   ...                   ...
# 28327       28327  AVqkIhxunnc1JgDc3kg_  2017-03-06T14:59:43Z
# 28328       28328  AVqkIhxunnc1JgDc3kg_  2017-03-06T14:59:43Z
# 28329       28329  AVqkIhxunnc1JgDc3kg_  2017-03-06T14:59:43Z
# 28330       28330  AVqkIhxunnc1JgDc3kg_  2017-03-06T14:59:43Z
# 28331       28331  AVqkIhxunnc1JgDc3kg_  2017-03-06T14:59:43Z
#
#                 dateUpdated  \
# 0      2019-04-25T09:08:16Z
# 1      2019-04-25T09:08:16Z
# 2      2019-04-25T09:08:16Z
# 3      2019-04-25T09:08:16Z
# 4      2019-04-25T09:08:16Z
# ...                     ...
# ...

# %%
data3=pd.read_csv('C:/Users/KIIT/Documents/minor/analyzed_data_textblob3.csv')

# %%
data1
# Out:
#       Unnamed: 0                    id       asins   brand  \
# 0              0  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 1              1  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 2              2  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 3              3  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# 4              4  AVpe7AsMilAPnD_xQ78G  B00QJDU3KY  Amazon
# ...          ...                   ...         ...     ...
# 1592        1592  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1593        1593  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1594        1594  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1595        1595  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
# 1596        1596  AVpfo9ukilAPnD_xfhuj  B00NO8JJZW  Amazon
#
#                                              categories colors  \
# 0                            Amazon Devices,mazon.co.uk    NaN
# 1                            Amazon Devices,mazon.co.uk    NaN
# 2                            Amazon Devices,mazon.co.uk    NaN
# ...

# %%
###

# %%
sample_pos = data3[data3['review_analysis']=='Positive'][:500]

# %%
sample_neg = data3[data3['review_analysis']=='Negative'][:500]

# %%
sample_nt = data3[data3['review_analysis']=='Neutral'][:500]

# %%
sample_pos
# Out:
#      Unnamed: 0                    id             dateAdded  \
# 2             2  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 3             3  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 4             4  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 5             5  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 6             6  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# ..          ...                   ...                   ...
# 648         648  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 649         649  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 650         650  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 652         652  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
# 653         653  AVpgNzjwLJeJML43Kpxn  2015-10-30T08:59:32Z
#
#               dateUpdated                                               name  \
# 2    2019-04-25T09:08:16Z  AmazonBasics AAA Performance Alkaline Batterie...
# 3    2019-04-25T09:08:16Z  AmazonBasics AAA Performance Alkaline Batterie...
# ...

# %%
sample_pos_selected = sample_pos.loc[:, ['id', 'name', 'reviews.rating', 'reviews.text', 'reviews.title', 'subjectivity', 'polarity', 'review_analysis']]

# %%
sample_pos_selected.head(5)
# Out:
#                      id                                               name  \
# 2  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 3  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 4  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 5  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 6  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
#
#    reviews.rating                                       reviews.text  \
# 2               5  Well they are not Duracell but for the price i...
# 3               5  Seem to work as well as name brand batteries a...
# 4               5  These batteries are very long lasting the pric...
# 5               5  Bought a lot of batteries for Christmas and th...
# 6               5  ive not had any problame with these batteries ...
#
#                                        reviews.title  subjectivity  polarity  \
# ...

# %%
sample_neg_selected = sample_neg.loc[:, ['id', 'name', 'reviews.rating', 'reviews.text', 'reviews.title', 'subjectivity', 'polarity', 'review_analysis']]

# %%
sample_neg_selected
# Out:
#                         id                                               name  \
# 0     AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 1     AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 8     AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 16    AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 19    AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# ...                    ...                                                ...
# 5969  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 5970  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 5972  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 5974  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 5976  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
#
# ...

# %%
sample_nt_selected = sample_nt.loc[:, ['id', 'name', 'reviews.rating', 'reviews.text', 'reviews.title', 'subjectivity', 'polarity', 'review_analysis']]

# %%
sample_nt_selected
# Out:
#                         id                                               name  \
# 47    AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 57    AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 64    AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 75    AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 80    AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# ...                    ...                                                ...
# 3724  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 3725  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 3726  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 3727  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 3728  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
#
# ...

# %%
selected_sample = pd.concat([sample_pos_selected,sample_neg_selected,sample_nt_selected])

# %%
selected_sample
# Out:
#                         id                                               name  \
# 2     AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 3     AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 4     AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 5     AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 6     AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# ...                    ...                                                ...
# 3724  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 3725  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 3726  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 3727  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
# 3728  AVpgNzjwLJeJML43Kpxn  AmazonBasics AAA Performance Alkaline Batterie...
#
# ...

# %%
selected_sample.to_csv('C:/Users/KIIT/Documents/minor/analyzed_selected_sample500.csv')

# %%
import sklearn

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix

# Load dataset into a pandas dataframe
df = pd.read_csv('sentiment_dataset.csv')

# Split dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(df['text'], df['sentiment'], test_size=0.3, random_state=42)

# Vectorize text data using TfidfVectorizer
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# Train and evaluate Naive Bayes model
nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)
y_pred_nb = nb_model.predict(X_test)
accuracy_nb = accuracy_score(y_test, y_pred_nb)
confusion_matrix_nb = confusion_matrix(y_test, y_pred_nb)

# Train and evaluate SVM model
svm_model = SVC()
svm_model.fit(X_train, y_train)
y_pred_svm = svm_model.predict(X_test)
accuracy_svm = accuracy_score(y_test, y_pred_svm)
confusion_matrix_svm = confusion_matrix(y_test, y_pred_svm)

# Train and evaluate Random Forest model
rf_model = RandomForestClassifier()
rf_model.fit(X_train, y_train)
y_pred
